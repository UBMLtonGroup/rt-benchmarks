# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = np.loadtxt('cdf.txt')

# %%
num_bins = 20
counts, bin_edges = np.histogram(data, bins=num_bins, normed=True)
cdf = np.cumsum(counts)

# %%
plt.plot(bin_edges[1:], cdf)

# %%
sorted_data = np.sort(data)

yvals=np.arange(len(sorted_data))/float(len(sorted_data)-1)

plt.plot(sorted_data,yvals)

# %%
data2 = np.loadtxt('cdf-hask.txt')
#data2 = [x for x in data2 if x < 1000]
num_bins = 20
counts2, bin_edges2 = np.histogram(data2, bins=num_bins, normed=True)
cdf2 = np.cumsum(counts2)
plt.plot(bin_edges2[1:], cdf2)

# %%
sorted_data2 = np.sort(data2)
yvals2=np.arange(len(sorted_data2))/float(len(sorted_data2)-1)
plt.xscale('log')
plt.plot(sorted_data2,yvals2, 'r-', sorted_data,yvals,'bs' )
