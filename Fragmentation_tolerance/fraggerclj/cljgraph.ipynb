# %%
import matplotlib.pyplot as plt
import csv
import numpy as np
# %matplotlib inline

# %%
x, y = np.loadtxt('cljfrag.txt', delimiter=',', unpack=True)

plt.plot(x,y, label='Time to allocate\n large array \n on fragmented heap')

plt.xlabel('Heap size (MB)')
plt.ylabel('Time (ms)')
plt.title('CLojure Fragmentation tolerance')
plt.legend()
plt.show()
